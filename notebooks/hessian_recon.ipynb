# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from hessian_recon import hessian
import tifffile as tf
import matplotlib.pyplot as plt
import numpy as np
initial = tf.imread('/Users/talley/Dropbox (HMS)/MATLAB/Packages/SIM/Hessian_SIM/raw-data/SIM-Wiener/re-Actin_97hz_0.5ms exposure raw data.tif')
plt.imshow(initial[0])
plt.show()

# %%
np.fft.fftn([1, -2, 1], sizex)
# Out:
# [autoreload of hessian_recon failed: Traceback (most recent call last):
#   File "/Users/talley/miniconda3/envs/gpu/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 245, in check
#     superreload(m, reload, self.old_objects)
#   File "/Users/talley/miniconda3/envs/gpu/lib/python3.7/site-packages/IPython/extensions/autoreload.py", line 434, in superreload
#     module = reload(module)
#   File "/Users/talley/miniconda3/envs/gpu/lib/python3.7/imp.py", line 314, in reload
#     return importlib.reload(module)
#   File "/Users/talley/miniconda3/envs/gpu/lib/python3.7/importlib/__init__.py", line 169, in reload
#     _bootstrap._exec(spec, module)
#   File "<frozen importlib._bootstrap>", line 630, in _exec
#   File "<frozen importlib._bootstrap_external>", line 724, in exec_module
#   File "<frozen importlib._bootstrap_external>", line 860, in get_code
#   File "<frozen importlib._bootstrap_external>", line 791, in source_to_code
# ...
